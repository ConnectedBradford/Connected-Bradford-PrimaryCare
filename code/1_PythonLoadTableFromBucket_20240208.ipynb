# %%
from google.cloud import bigquery
from google.cloud.bigquery import LoadJobConfig
from google.cloud.bigquery import SchemaField

client = bigquery.Client()
dataset_ref = client.dataset('CB_MYSPACE_JDB')
# Out:
# /opt/conda/lib/python3.7/site-packages/google/auth/_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /opt/conda/lib/python3.7/site-packages/google/auth/_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
##### Create the table tbl_SRAppointment

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateStart', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEnd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('AppointmentStatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateAppointmentBooked', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DatePatientArrival', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DatePatientSeen', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('FollowUpAppointment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TelephoneAppointment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDClinician', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileClinician', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RotaName', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RotaType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RotaLocation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RotaCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDRotaOwner', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileRotaOwner', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('AllowsOverbooking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('BookingContactNumber', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateAppointmentCancelled', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDRota', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIN', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE') ,
bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]

table_ref = dataset_ref.table('tbl_SRAppointment')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data fro SRAppointment

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRAppointment.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRAppointment - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRCHSStatusHistory

schema = [
    bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CHSStatusGroup', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CHSStatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRCHSStatusHistory')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data


#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRCHSStatusHistory.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRCHSStatusHistory - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRCode


schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CTV3Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CTV3Text', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SNOMEDCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SNOMEDText', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NumericComparator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IsNumeric', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NumericValue', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NumericUnit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('EpisodeType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDTemplate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIN', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDAppointment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDVisit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE') ,
bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRCode')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
#table = client.create_table(table)  # API request

## Loading data

##tbl_SRCode


#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="~"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRCode.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRCode - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRCodeTemplateLink

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDTemplateRecording', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDTemplate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE') ,  
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE') ,
bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRCodeTemplateLink')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
#table = client.create_table(table)  # API request

## Loading data

##tbl_SRCodeTemplateLink

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRCodeTemplateLink.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRCodeTemplateLink - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRConfiguredListOption

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ConfiguredList', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ConfiguredListOption', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CDSCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CAMHSCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MHSDSCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE') ,
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRConfiguredListOption')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data

##tbl_SRConfiguredListOption

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRConfiguredListOption.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRConfiguredListOption - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRDrugSensitivity
schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateStarted', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEnded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('FormulationSpecific', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDrugCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDMultiLexAction', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIn', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRDrugSensitivity')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

##tbl_SRDrugSensitivity


#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRDrugSensitivity.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRDrugSensitivity - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SREvent

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDStaffMemberProfileRole', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDAuthorisedBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileAuthorisedBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ContactEventLocation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ContactMethod', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('EventIncomplete', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ClinicalEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDTeam', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDBranch', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DuplicateData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_record_added', 'STRING', mode='NULLABLE'),

]
table_ref = dataset_ref.table('tbl_SREvent')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

##tbl_SREvent

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SREvent.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SREvent - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SREventLink

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDAppointment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDVisit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SREventLink')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data


#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SREventLink.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SREventLink - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRGPPracticeHistory

schema = [
  bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPractice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileRegisteredGP', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateFrom', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),  
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRGPPracticeHistory')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRGPPracticeHistory.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRGPPracticeHistory - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRGoal

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GoalCategory', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GoalType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GoalOutcome', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GoalImportance', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateGoalTarget', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ActionPlanCategory', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ActionPlanPatientConfidence', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ActionPlanOutcome', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEndedActionPlan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GoalPerformance', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'),
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRGoal')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data



#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRGoal.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRGoal - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRImmunisation

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDVaccination', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDImmunisationContent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Dose', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Location', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Method', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateExpiry', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ImmsReadCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('VaccPart', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('VaccBatchNumber', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('VaccAreaCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('VaccinationStatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRImmunisation')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data



#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRImmunisation.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRImmunisation - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRImmunisationConsent

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ConsentedToVacc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RefusalOrConsentCurrent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEnded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('VaccName', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('VaccContent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE') ,   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE') ,
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRImmunisationConsent')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data


#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRImmunisationConsent.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRImmunisationConsent - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRImmunisationContent

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Content', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateDeleted', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DuplicateData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_record_added', 'STRING', mode='NULLABLE'),

]
table_ref = dataset_ref.table('tbl_SRImmunisationContent')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data



#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="~"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRImmunisationContent.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRImmunisationContent - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRMapping

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IdMappingGroup', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Mapping', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE') ,   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE') ,
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRMapping')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data


#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRMapping.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRMapping - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRMappingGroup

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GroupName', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE') ,  
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE') ,
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRMappingGroup')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data


#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRMappingGroup.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRMappingGroup - Loaded {} rows.'.format(destination_table.num_rows))



## Create the table tbl_SRMedicationReadCodeDetails
schema = [

bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDMultiLexProduct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DrugReadCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DrugReadCodeDesc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE') ,   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE') ,
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRMedicationReadCodeDetails')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data


#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRMedicationReadCodeDetails.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRMedicationReadCodeDetails - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SROnlineServices

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ViewRecord', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Appointments', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Prescriptions', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Questionnaires', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SummaryCareRecord', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateDeleted', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileDeletedBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DetailedCodedRecord', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOnlineUser', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SROnlineServices')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data


#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SROnlineServices.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SROnlineServices - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SROrganisation

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ID', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('HouseName', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('HouseNumber', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NameOfRoad', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NameOfLocality', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NameOfTown', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NameOfCounty', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('FullPostCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Telephone', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SecondaryTelephone', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Fax', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MadeObsolete', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDTrust', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDCcg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DuplicateData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_record_added', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Endo','STRING', mode='NULLABLE'), 
]
table_ref = dataset_ref.table('tbl_SROrganisation')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SROrganisation.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SROrganisation - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SROrganisationBranch

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ID', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('BranchName', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('HouseName', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('HouseNumber', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RoadName', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Locality', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Town', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('County', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PostCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('BranchObsolete', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE'), 

]
table_ref = dataset_ref.table('tbl_SROrganisationBranch')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SROrganisationBranch.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SROrganisationBranch - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SROverseasVisitorChargingCategory

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('OverseasVisitorChargingCategory', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIn', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SROverseasVisitorChargingCategory')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data


#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SROverseasVisitorChargingCategory.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SROverseasVisitorChargingCategory - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRPatient

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateBirth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateDeath', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('BirthPlace', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Gender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SpeaksEnglish', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TestPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SSRef', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SpineMatched', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Ethnicity', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('LanguageSpoken', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SOA', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Ward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Religion', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'),
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRPatient')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data



#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRPatient.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRPatient - Loaded {} rows.'.format(destination_table.num_rows))



## Create the table tbl_SRPatientAddressHistory

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PartialPostCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('AddressType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CcgOfResidence', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRPatientAddressHistory')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table)
table = client.create_table(table)  # API request

## Loading data


#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRPatientAddressHistory.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRPatientAddressHistory - Loaded {} rows.'.format(destination_table.num_rows))



## Create the table tbl_SRPatientGroups

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GroupType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Members', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateRemoved', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDStaffRemoved', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileRemoved', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRPatientGroups')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data


#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRPatientGroups.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRPatientGroups - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRPatientRegistration

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateRegistration', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateDeRegistration', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RegistrationStatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PreferredPharmacy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data' ,'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRPatientRegistration')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRPatientRegistration.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRPatientRegistration - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRPatientRelationship

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEnded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RelationshipType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PersonalGuardianOrProxy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NextOfKin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CaresForPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PrincipalCarerForPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('KeyHolder', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('HasParentalResponsibility', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('FinancialRepresentative', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Advocate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MainVisitor', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CallCentreCallBackConsent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CopyCorrespondence', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ContactOrder', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ContactMethod', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CommunicationFormat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('InterpreterRequired', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDRelationshipWithPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatientRelationshipWith', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CodeRelationshipWithUser', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RelationshipWithOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRPatientRelationship')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRPatientRelationship.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRPatientRelationship - Loaded {} rows.'.format(destination_table.num_rows))


## Create the table tbl_SRPersonAtRisk

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateAdded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ProtectionPlan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateRemoved', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileRemovedBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRPersonAtRisk')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRPersonAtRisk.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRPersonAtRisk - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRPrimaryCareMedication

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDMultiLexProduct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDMultiLexPack', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDMultiLexDMD', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NameOfMedication', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateMedicationStart', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateMedicationEnd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MedicationDosage', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MedicationQuantity', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IsSupervised', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SupervisedDose', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('UnSupervisedDose', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IsRepeatMedication', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IsOtherMedication', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IsDentalMedication', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IsHospitalMedication', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDRepeatTemplate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIN', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRPrimaryCareMedication')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRPrimaryCareMedication.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRPrimaryCareMedication - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRProblem

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CTV3Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEnd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Severity', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIN', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'),
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRProblem')
table = bigquery.Table(table_ref, schema=schema)
#table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="~"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRProblem.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRProblem - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRRecall

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateRecall', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RecallType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RecallInitialStatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RecallStatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RecallStatusDate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIN', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRRecall')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRRecall.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRRecall - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRReferralIn

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PrimaryReason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateReferral', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateOnReferralLetter', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Source', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ServiceOffered', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ServiceType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ReReferral', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Urgency', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDCodePrimaryDiagnosis', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ReferralCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralLocal', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ReasonForServiceDelay', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Outcome', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DefaultContactLocation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateDischargeScheduled', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateDischarge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DischargeReason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DischargeLocation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferrer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SourceTableReferrer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PatientAware', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateOfAction', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ActiveStatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ReferredToSpeciality', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ReferredToTreatmentCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferredTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SourceTableReferrerTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ReferralPriority', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ReferralMedium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateOfDecision', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DayCareReferral', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MaternityReferral', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Commissioner', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ClientCategory', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PrimarySupportReason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDCaseload', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ReferralEndReason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('HospitalReferralSourceCdsCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('M101140ReasonForOutOfAreaReferralAdultAcuteMentalHealth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('HospitalReferredForType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRReferralIn')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRReferralIn.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRReferralIn - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRReferralInIntervention

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Intervention', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIN', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRReferralInIntervention')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRReferralInIntervention.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRReferralInIntervention - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRReferralInReferralReason

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PrimaryReferralReason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ReferralReason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateRemoved', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIN', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRReferralInReferralReason')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRReferralInReferralReason.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRReferralInReferralReason - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRReferralInStatusDetails

schema = [

bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('StatusOfReferralIN', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIn', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRReferralInStatusDetails')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRReferralInStatusDetails.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRReferralInStatusDetails - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRReferralOut

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TypeOfReferral', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileReferrer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ServiceOffered', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ReReferral', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Urgency', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PrimaryDiagnosis', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RecipientID', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RecipientIDType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('M101140ReasonForOutOfAreaReferralAdultAcuteMentalHealth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'),
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRReferralOut')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRReferralOut.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRReferralOut - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRReferralOutStatusDetails

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('StatusOfReferralOut', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralOut', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRReferralOutStatusDetails')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRReferralOutStatusDetails.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRReferralOutStatusDetails - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRRepeatTemplate

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDMultiLexProduct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDMultiLexPack', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDMultiLexDMD', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NameOfMedication', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateMedicationTemplateStart', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateMedicationTemplateEnd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateMedicationTemplateReview', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MedicationDosage', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MedicationQuantity', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MaxIssues', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CourseLengthPerIssue', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DrugStatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIN', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRRepeatTemplate')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRRepeatTemplate.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRRepeatTemplate - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRRota

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateCreation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileCreatedBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RotaType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Location', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileOwner', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('AllowOverbooking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('BookingContactNumber', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDAppointmentRoom', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDBranch', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'),
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRRota')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRRota.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRRota - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRRotaSlot

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDRota', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RotaSlotType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Duration', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Quantity', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('EmbargoDuration', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('EmbargoExpiryTime', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('BlockedSlot', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('BookableCAnB', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('OldRowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRRotaSlot')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRRotaSlot.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRRotaSlot - Loaded {} rows.'.format(destination_table.num_rows))


## Create the table tbl_SRSmsConsent

schema = [
  bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SmsConsent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),  
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRSmsConsent')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRSmsConsent.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRSmsConsent - Loaded {} rows.'.format(destination_table.num_rows))

# %%
## Create the table tbl_SRStaffMember

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('StaffName', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('StaffUserName', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NationalIdType', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDNational', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDSmartCard', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Obsolete', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DuplicateData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_record_added', 'STRING', mode='NULLABLE'),
]
table_ref = dataset_ref.table('tbl_SRStaffMember')
table = bigquery.Table(table_ref, schema=schema)
#table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRStaffMember.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRStaffMember - Loaded {} rows.'.format(destination_table.num_rows))
# Out:
# tbl_SRStaffMember - Loaded 3070779 rows.

# %%
## Create the table tbl_SRStaffMemberProfile

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateProfileCreated', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileCreatedBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDStaffMemberProfileRole', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('StaffRole', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEmploymentStart', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEmploymentEnd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PPAID', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GPLocalCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDStaffMember', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GmpID', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRStaffMemberProfile')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRStaffMemberProfile.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRStaffMemberProfile - Loaded {} rows.'.format(destination_table.num_rows))
# Out:
# tbl_SRStaffMemberProfile - Loaded 17978260 rows.

# %%
## Create the table tbl_SRStaffMemberProfileRole 

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RoleDescription', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IsSpineRole', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateLastAmended', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateDeleted', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'),
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRStaffMemberProfileRole')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRStaffMemberProfileRole.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRStaffMemberProfileRole  - Loaded {} rows.'.format(destination_table.num_rows))
# Out:
# tbl_SRStaffMemberProfileRole  - Loaded 0 rows.

# %%
## Create the table tbl_SRTemplate

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DatePublished', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfilePublishedBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TemplateName', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TemplateVersion', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRTemplate')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRTemplate.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRTemplate - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRTrust

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateCreated', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IdProfileCreatedBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('OdsCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('HouseName', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('HouseNumber', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NameOfRoad', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NameofLocality', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NameOfTown', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NameOfCounty', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('FullPostCode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Telephone', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SecondaryTelephone', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Fax', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRTrust')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRTrust.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRTrust - Loaded {} rows.'.format(destination_table.num_rows))

## Create the table tbl_SRVariableDoseCDMedication

schema = [
 bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('TextualEventDoneBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationDoneAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDMultiLexProduct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDMultiLexPack', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDMultiLexDMD', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NameOfMedication', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateMedicationStart', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateMedicationEnd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MedicationCourseLength', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SupervisedDose', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MedicationEndReason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileMedicationEndedBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIn', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDEvent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),   
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'), 
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRVariableDoseCDMedication')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRVariableDoseCDMedication.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRVariableDoseCDMedication - Loaded {} rows.'.format(destination_table.num_rows))

# %%
## Create the table tbl_SRVisit

schema = [
bigquery.SchemaField('RowIdentifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationVisibleTo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateEventRecorded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileEnteredBy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateBooked', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DateRequested', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CurrentStatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileRequested', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDProfileAssigned', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('FollowUpDetails', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDReferralIN', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDPatient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Duration', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IDOrganisationRegisteredAt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('RemovedData', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_loadnum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_exported_to_sde', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cb_rowid', 'STRING', mode='NULLABLE'),    
bigquery.SchemaField('cb_duplicate_data', 'STRING', mode='NULLABLE'),
    bigquery.SchemaField('cb_record_added','STRING', mode='NULLABLE') 
]
table_ref = dataset_ref.table('tbl_SRVisit')
table = bigquery.Table(table_ref, schema=schema)
table = client.create_table(table)  # API request

## Loading data

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://bucket_autoload/tbl_SRVisit.txt'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('tbl_SRVisit - Loaded {} rows.'.format(destination_table.num_rows))
# Out:
# tbl_SRVisit - Loaded 3948 rows.
